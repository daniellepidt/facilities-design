# %% [markdown]
# # Plot tests file:
# This file is used to try out various ways of plotting the simulation on the fly.

# %%
import numpy as np
c = np.random.randint(90, 120, size=(8,2,16))
c[c < 100] = 0
c
# Out:
# array([[[116, 108, 115, 110,   0, 116,   0,   0, 104,   0, 100,   0,
#            0, 109, 109,   0],
#         [  0, 117, 115,   0,   0, 112, 110, 104, 111,   0, 103, 105,
#          108,   0,   0, 109]],
#
#        [[107, 111,   0,   0, 111, 112, 111,   0,   0, 116,   0,   0,
#          111, 118,   0, 113],
#         [113, 110,   0, 103, 116, 118, 109, 111, 101, 113, 117, 102,
#            0, 108, 113, 104]],
#
#        [[102,   0,   0, 113, 116,   0, 119, 116, 116, 103, 104, 109,
#          108, 112, 103, 100],
#         [  0, 108, 116, 101, 107, 105, 111, 101, 110,   0, 104, 103,
#            0, 107,   0,   0]],
#
#        [[108, 102, 117, 102, 109, 100, 101, 110,   0, 102, 105, 119,
#          108,   0,   0, 109],
#         [105, 109,   0,   0,   0, 115, 115,   0,   0, 119, 102, 110,
#            0, 114,   0, 109]],
#
#        [[114,   0, 118,   0, 119, 110, 108, 100, 101, 114, 119, 116,
#          116, 108, 114, 102],
#         [117, 115, 101, 109,   0, 117,   0, 114,   0, 103,   0, 106,
#          104,   0, 105,   0]],
#
#        [[101,   0, 109, 118, 119,   0,   0,   0, 100, 110,   0,   0,
#          103,   0, 105, 106],
#         [  0,   0, 102, 101,   0,   0, 102,   0, 119, 105, 112,   0,
#            0, 107, 108, 110]],
#
#        [[  0,   0, 112, 116,   0, 111, 102,   0,   0, 104, 107, 105,
#          110, 119,   0, 115],
#         [  0,   0, 100, 100, 112,   0, 100, 105, 104, 105, 105, 114,
#          118,   0,   0, 100]],
#
#        [[  0,   0, 108,   0, 109,   0, 112, 119,   0, 101, 104, 113,
#          115, 115, 102,   0],
#         [112, 112,   0, 103, 113, 116, 114, 114, 115,   0, 117, 117,
#          102, 104, 107,   0]]])

# %%
flat = c.flatten()
flat = flat[flat != 0]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(projection='3d')

z,x,y = c.nonzero() 
scatter = ax.scatter(x,y,z, c=flat, alpha=1)

legend1 = ax.legend(*scatter.legend_elements(),
                    loc="upper center", title="Item Type", ncol=5, fancybox=True, shadow=True)
ax.add_artist(legend1)

ax.set_xlabel('Aisle Side')
ax.set_ylabel('Aisle Depth')
ax.set_zlabel('Aisle Height')
plt.xticks([0,1], ['Left', 'Right'])
plt.yticks(np.arange(1,17, step=2), np.arange(1,17, step=2))
ax.set_zticks(np.arange(0,8), np.arange(1,9))
plt.show()
